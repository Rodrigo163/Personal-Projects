# %% [markdown]
# # Filament detection and segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.data as data
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color
import imageio as iio
import scipy.ndimage as ndi

# %%
im = iio.imread('multifil.PNG')
im = color.rgb2gray(im) 

def im_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax
im_show(im)
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23542887748>)

# %% [markdown]
# # 1st approach: basic thresholding

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(im.ravel(), bins=100, range=[0, 1])
ax.set_xlim(0, 1);

# %% [markdown]
# ### Supervised Thresholding

# %%
mask = np.where(im > 0.2,im, 0)
im_show(mask)
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23545ab5828>)

# %% [markdown]
# ### Unsupervised Thresholding
# Tons of options to try!

# %%
im_threshold = filters.threshold_otsu(im)  
im_show(np.where(im > im_threshold, im, np.NaN))
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23545b16630>)

# %%
im_threshold = filters.threshold_li(im)  
im2 = np.where(im > im_threshold, im, np.NaN)
im_show(im2)
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23545b661d0>)

# %% [markdown]
# ## Once we have the processed image

# %%
labels, nobjects = ndi.label(mask)
nobjects
# Out:
# 18

# %%
plt.imshow(labels)
plt.axis('off')
plt.show()

# %%
boxes = ndi.find_objects(labels)
object_0 = mask[boxes[0]]
object_1 = mask[boxes[1]]
im_show(object_0, cmap='gray')
# Out:
# (<Figure size 1008x1008 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23545c1d390>)

# %%
def backbone_detection(im):
    r, c = im.shape
    maxs = []
    for i in range(r):
        maxs.append([i, np.argmax(im[i])])
    backbone = np.zeros([r,c])
    for i in range(r):
        for j in range(c):
            if j == maxs[i][1]:
                backbone[i][j] = 1
    fig, ax = plt.subplots(1,2)
    ax[0].imshow(im)
    ax[1].imshow(backbone)
    plt.show()

# %%
def backbone_detection2(im):
    imt = im.transpose()
    r, c = im.shape
    maxs1 = []
    maxs2 = []
    for i in range(r):
        maxs1.append([i, np.argmax(im[i])])
    for i in range(c):
        maxs2.append([i, np.argmax(imt[i])])
    backbone1 = np.zeros([r,c])
    backbone2 = np.zeros([c, r])
    for i in range(r):
        for j in range(c):
            if j == maxs1[i][1]:
                backbone1[i][j] = 1
    for i in range(c):
        for j in range(r):
            if j == maxs2[i][1]:
                backbone2[i][j] = 1
    backbone = backbone1 + backbone2.transpose()
    fig, ax = plt.subplots(1,2)
    ax[0].imshow(im)
    ax[0].axis('off')
    ax[1].imshow(backbone)
    ax[1].axis('off')
    plt.show()

# %%
backbone_detection2(object_0)

# %%
backbone_detection2(object_1)
